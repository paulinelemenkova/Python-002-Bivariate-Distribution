# %%
import seaborn as sb
from matplotlib import pyplot as plt
import pandas as pd
import os
os.chdir('/Users/pauline/Documents/Python')
dfM = pd.read_csv("Tab-Morph.csv")
dfM.head(5)
sb.jointplot(x='slope_angle',y='sedim_thick',kind="reg", data=dfM)
plt.show()
